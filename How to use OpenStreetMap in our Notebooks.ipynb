# %% [markdown]
# # How to use OpenStreetMap in our Notebooks
#
# In this tutorial, we will be using OSMnx to perform OSM tasks. We will start with setting it up.
#
# OSMnx is a Python package that lets you download spatial geometries and model project, visualize, and analize street network and other spatial data from OpenStreetMap's API.
# Since OSMnx is a package, we should start with installing it first. And if you need to install a package that is not already available on your machine, you need to open the conda environment from your Start Menu (if you are on a Windows) and use the command window to type the following command:
# ```python
# conda install osmnx
# ```
# ![conda isntall osmx](conda_install_osmx.png)

# %% [markdown]
# Once you successfully type the comment and press the enter, the following lines will start to be printed on the command window:

# %% [markdown]
# ![installing osmx](installing_osmnx.png)

# %% [markdown]
# It will as you if you would like to proceed or not, type *y* and press enter to continue. Once the installation finishes, Then, you are ready to use it in your notebooks or any other python script that you are going to write.

# %%
import osmnx as ox

# %% [markdown]
# Here, you might wonder why we have ox? Sometimes, if we are going to use the functions available under a package, we need dot(.) notation to call those functions.And if this is going to be repeated multiple times, it is good to have a shorter acroynm so we don't have to type the full package name again and again. Other common examples are
# - importing pandas as pd,
# - importing numpy as np, and
# - importing matplotlib as plt.

# %% [markdown]
# ## ACQUIRE  THE DATASET

# %% [markdown]
# It is not visible yet but since we imported osmnx, now we can access entire world! Let's try! LEt's create a variable place and select our favorite city:

# %%
place ='Manhattan, New York, USA'

# %% [markdown]
# Now, assume we would like to go to Manhattan and acquire some Point of Interests (POIs) as cafes. See whatelse you can choose as <a href="https://wiki.openstreetmap.org/wiki/Key:amenity">**"amenity"**</a>.
#
# Under OSMnx , there is a dictionary object called *geometries_from_place()* function and we can use call it as follows:

# %%
tags ={'amenity':'cafe'}
cafe=ox.geometries_from_place(place, tags=tags)

cafe.head()
# Out:
#                        addr:housenumber addr:postcode      addr:street  \
# element_type osmid
# node         410235438              975         10025  Columbus Avenue
#              419367394              NaN           NaN              NaN
#              419367529              NaN           NaN              NaN
#              560636265              NaN           NaN              NaN
#              561239802              564         10016       3rd Avenue
#
#                        amenity             name                    geometry  \
# element_type osmid
# node         410235438    cafe     Zanny's Cafe  POINT (-73.96182 40.80037)
#              419367394    cafe        Perk Kafe  POINT (-73.97726 40.74771)
#              419367529    cafe     Lenox Coffee  POINT (-73.94318 40.81001)
#              560636265    cafe        Starbucks  POINT (-74.01413 40.70328)
#              561239802    cafe  Cafe Delecctica  POINT (-73.97663 40.74816)
#
#                                      cuisine drink:coffee drink:espresso  \
# element_type osmid
# node         410235438                   NaN          NaN            NaN
#              419367394           coffee_shop          yes            yes
#              419367529           coffee_shop          NaN            NaN
#              560636265           coffee_shop          NaN            NaN
#              561239802  coffee_shop;sandwich          yes            yes
#
#                        internet_access  ... building:colour building:levels  \
# element_type osmid                      ...
# node         410235438             NaN  ...             NaN             NaN
#              419367394            wlan  ...             NaN             NaN
#              419367529            wlan  ...             NaN             NaN
#              560636265             NaN  ...             NaN             NaN
#              561239802             NaN  ...             NaN             NaN
#
#                        building:material roof:material roof:shape roof:colour  \
# element_type osmid
# node         410235438               NaN           NaN        NaN         NaN
#              419367394               NaN           NaN        NaN         NaN
#              419367529               NaN           NaN        NaN         NaN
#              560636265               NaN           NaN        NaN         NaN
#              561239802               NaN           NaN        NaN         NaN
#
#                        addr:block indoor surveillance indoor_seating
# element_type osmid
# node         410235438        NaN    NaN          NaN            NaN
#              419367394        NaN    NaN          NaN            NaN
#              419367529        NaN    NaN          NaN            NaN
#              560636265        NaN    NaN          NaN            NaN
#              561239802        NaN    NaN          NaN            NaN
#
# [5 rows x 178 columns]

# %% [markdown]
# How we have our data points, let's see them on a map by using <a href="https://python-visualization.github.io/folium/"> Folium!

# %%
import folium

# %%
cafe_points = cafe[cafe.geom_type =='Point'][:100]

# %% [markdown]
# First we need to create a Map object that we will use as a base map, then we need to use Marker function to visualize our points on that base map.

# %%
m = folium.Map([40.754932, -73.984016], zoom_start=10) #why do we specify the lat and long? Where do you think we will be zooming into?

# %% [markdown]
# What are the inputs for <a href="https://python-visualization.github.io/folium/quickstart.html#Markers">**folium.Marker()**</a> ?

# %% [markdown]
# OK. So we need to pass our locations to the ``` folium.Marker()``` as a parameter. We have the map, we have the geopandas which holds our points, but how our map will know where those points are located? Can you find by looking at the table? Which column(s) do we need to access? Which door do we have to knock (dot) ?

# %%
latitudes= cafe_points.geometry.x
longitudes = cafe_points.geometry.y

# %% [markdown]
# Finally, we can get the latitudes and longitudes. Now it is time to zip them up! Let's check <a href="https://www.w3schools.com/python/ref_func_zip.asp">this</a> first.

# %%
locs = zip(cafe_points.geometry.y, cafe_points.geometry.x)

names = cafe_points.name

for location,name in zip(locs,names):
    
    folium.Marker(location=location, popup=name).add_to(m) 
    
m

# %% [markdown]
# You can save your map as an html:

# %%
m.save('cafes.html')

# %% [markdown]
# ## What about Museums? Can you get the museums?

# %% [markdown]
# **Hint** : You can check the <a href="https://wiki.openstreetmap.org/wiki/Map_features"> **link** </a> to see how we can get more tags.
#     Also, feel free to customize your map by checking <a href="https://python-visualization.github.io/folium/quickstart.html#Markers">**other markers**</a>.

# %%
tags={'tourism':'museum'}
museums=ox.geometries_from_place(place, tags=tags)
museums.head()
# Out:
#                        gnis:county_name gnis:feature_id  \
# element_type osmid
# node         368052081         New York         2057419
#              368061337              NaN         2057415
#              368061605         New York         2091590
#              368061607         New York         2091587
#              368061657         New York         2080645
#
#                                             gnis:import_uuid  \
# element_type osmid
# node         368052081  57871b70-0100-4405-bb30-88b2e001a944
#              368061337                                   NaN
#              368061605  57871b70-0100-4405-bb30-88b2e001a944
#              368061607                                   NaN
#              368061657  57871b70-0100-4405-bb30-88b2e001a944
#
#                                                           name tourism  \
# element_type osmid
# node         368052081                  Fraunces Tavern Museum  museum
#              368061337  National Museum of the American Indian  museum
#              368061605               Yeshiva University Museum  museum
#              368061607                    Dahesh Museum of Art  museum
#              368061657                   Museum of African Art  museum
#
#                        wheelchair  wikidata                    geometry  \
# element_type osmid
# node         368052081        yes  Q2947539  POINT (-74.01135 40.70339)
#              368061337        yes  Q5539979  POINT (-74.01375 40.70403)
#              368061605        NaN  Q8052851  POINT (-73.99389 40.73778)
#              368061607        NaN  Q2999991  POINT (-74.00491 40.72510)
#              368061657        NaN       NaN  POINT (-73.99778 40.72500)
#
#                        addr:city addr:postcode  ... name:ja alt_name:cs  \
# element_type osmid                              ...
# node         368052081       NaN           NaN  ...     NaN         NaN
#              368061337  New York         10004  ...     NaN         NaN
#              368061605       NaN           NaN  ...     NaN         NaN
#              368061607       NaN           NaN  ...     NaN         NaN
#              368061657       NaN           NaN  ...     NaN         NaN
#
#                        alt_name:es name:cs name:pt area ways type name:hi  \
# element_type osmid
# node         368052081         NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061337         NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061605         NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061607         NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061657         NaN     NaN     NaN  NaN  NaN  NaN     NaN
#
#                        name:de
# element_type osmid
# node         368052081     NaN
#              368061337     NaN
#              368061605     NaN
#              368061607     NaN
#              368061657     NaN
#
# [5 rows x 117 columns]

# %%
museums_points = museums[museums.geom_type =='Point'][:100]

# %%
m2 = folium.Map([40.754932, -73.984016], zoom_start=10) # why I selected this particular location, 
                                                        # what happens if I don't specify it?
locs=zip(museums_points.geometry.y,museums_points.geometry.x)
museum_names = museums_points.name

for location,name in zip(locs,museum_names):
    folium.Marker(location=location, popup=name).add_to(m2) 
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4e991142f553425e994107b4fec0da72%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4e991142f553425e994107b4fec0da72%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4e991142f553425e994107b4fec0da72%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4e991142f553425e994107b4fec0da72%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# This exercise adapted from Juan Nathaniel's "Working with Open StreetMap in Python article.https://levelup.gitconnected.com/working-with-openstreetmap-in-python-c49396d98ad4
